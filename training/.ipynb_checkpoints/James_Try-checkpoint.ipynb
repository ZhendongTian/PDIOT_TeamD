# %%
import pandas as pd
import numpy as np
import tsfresh
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
import tensorflow as tf

import os

import matplotlib.pyplot as plt

# keras goodies
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Conv1D, Dropout, MaxPooling1D, BatchNormalization
from tensorflow.keras import optimizers
from tensorflow.keras import regularizers
from tensorflow.keras import metrics as kmetrics
import tensorflow.keras.backend as K

# %%
base_df = pd.DataFrame()

clean_data_folder = "./Data/Clean"

for filename in os.listdir(clean_data_folder):
    full_path = f"{clean_data_folder}/{filename}"
    print(full_path)
    
    # load data into a DataFrame
    new_df = pd.read_csv(full_path)
    
    # merge into the base DataFrame
    base_df = pd.concat([base_df, new_df])
# Out:
# ./Data/Clean/Respeck_s2250677_Climbing stairs_04-10-2021_16-23-49.csv
# ./Data/Clean/Respeck_s2250677_Descending stairs_04-10-2021_16-26-45.csv
# ./Data/Clean/Respeck_s2250677_Desk work_04-10-2021_16-29-06.csv
# ./Data/Clean/Respeck_s2250677_Falling on knees_04-10-2021_16-39-21.csv
# ./Data/Clean/Respeck_s2250677_Falling on the back_04-10-2021_16-43-09.csv
# ./Data/Clean/Respeck_s2250677_Falling on the left_04-10-2021_16-58-47.csv
# ./Data/Clean/Respeck_s2250677_Falling on the right_04-10-2021_16-57-15.csv
# ./Data/Clean/Respeck_s2250677_Lying down left_04-10-2021_16-13-38.csv
# ./Data/Clean/Respeck_s2250677_Lying down on back_04-10-2021_16-11-56.csv
# ./Data/Clean/Respeck_s2250677_Lying down on stomach_04-10-2021_16-16-54.csv
# ./Data/Clean/Respeck_s2250677_Lying down right_04-10-2021_16-14-52.csv
# ./Data/Clean/Respeck_s2250677_Movement_04-10-2021_16-30-39.csv
# ./Data/Clean/Respeck_s2250677_Running_04-10-2021_16-21-45.csv
# ./Data/Clean/Respeck_s2250677_Sitting bent backward_04-10-2021_16-08-21.csv
# ./Data/Clean/Respeck_s2250677_Sitting bent forward_04-10-2021_16-07-07.csv
# ./Data/Clean/Respeck_s2250677_Sitting_04-10-2021_16-06-14.csv
# ./Data/Clean/Respeck_s2250677_Standing_04-10-2021_16-09-34.csv
# ./Data/Clean/Respeck_s2250677_Walking at normal speed_04-10-2021_16-20-14.csv
# ./Data/Clean/Thingy_s2250677_Climbing stairs_06-10-2021_13-43-53.csv
# ./Data/Clean/Thingy_s2250677_Descending stairs_06-10-2021_13-45-01.csv
# ./Data/Clean/Thingy_s2250677_Desk work_06-10-2021_13-48-25.csv
# ./Data/Clean/Thingy_s2250677_Falling on knees_06-10-2021_13-49-57.csv
# ./Data/Clean/Thingy_s2250677_Falling on the back_06-10-2021_13-58-22.csv
# ./Data/Clean/Thingy_s2250677_Falling on the left_06-10-2021_13-53-42.csv
# ./Data/Clean/Thingy_s2250677_Falling on the right_06-10-2021_13-55-40.csv
# ./Data/Clean/Thingy_s2250677_Lying down left_06-10-2021_13-36-02.csv
# ./Data/Clean/Thingy_s2250677_Lying down on back_06-10-2021_13-35-16.csv
# ./Data/Clean/Thingy_s2250677_Lying down on stomach_06-10-2021_13-37-50.csv
# ./Data/Clean/Thingy_s2250677_Lying down right_06-10-2021_13-36-55.csv
# ./Data/Clean/Thingy_s2250677_Movement_06-10-2021_13-47-06.csv
# ./Data/Clean/Thingy_s2250677_Running_06-10-2021_13-41-40.csv
# ./Data/Clean/Thingy_s2250677_Sitting bent backward_06-10-2021_13-33-25.csv
# ./Data/Clean/Thingy_s2250677_Sitting bent forward_06-10-2021_13-32-31.csv
# ./Data/Clean/Thingy_s2250677_Sitting_06-10-2021_13-31-43.csv
# ./Data/Clean/Thingy_s2250677_Standing_06-10-2021_13-34-16.csv
# ./Data/Clean/Thingy_s2250677_Walking at normal speed_06-10-2021_13-40-35.csv

# %%
base_df
# Out:
#          timestamp   accel_x   accel_y   accel_z     gyro_x     gyro_y  \
# 0    1633357398910 -0.291992 -1.111877  0.116394   2.750000   0.468750
# 1    1633357398943 -0.238525 -1.236389  0.010193  11.781250  -1.734375
# 2    1633357399015 -0.321045 -1.407288 -0.164124   1.984375   5.203125
# 3    1633357399020  0.040039 -1.713440 -0.226868   9.171875   7.953125
# 4    1633357399094 -0.019531 -1.135315 -0.065491   3.703125  -6.703125
# ..             ...       ...       ...       ...        ...        ...
# 756  1633520435008 -1.315430 -0.021484  0.819336 -15.218750  -8.218750
# 757  1633520435069 -0.703125 -0.136719 -0.393555 -22.687500 -28.000000
# 758  1633520435097 -0.994141  0.189453  0.054688  49.468750  62.250000
# 759  1633520435129 -1.173828  0.170898  0.018555 -17.781250  84.062500
# 760  1633520435188 -0.809570  0.211914  0.183594 -24.687500  70.500000
#
#         gyro_z sensor_type            activity_type  activity_code subject_id  \
# 0     4.625000     Respeck          Climbing stairs             12   s2250677
# 1     9.546875     Respeck          Climbing stairs             12   s2250677
# 2    14.468750     Respeck          Climbing stairs             12   s2250677
# 3    16.796875     Respeck          Climbing stairs             12   s2250677
# 4   -11.781250     Respeck          Climbing stairs             12   s2250677
# ..         ...         ...                      ...            ...        ...
# 756  36.937500      Thingy  Walking at normal speed              1   s2250677
# 757 -12.562500      Thingy  Walking at normal speed              1   s2250677
# 758  21.500000      Thingy  Walking at normal speed              1   s2250677
# 759 -12.437500      Thingy  Walking at normal speed              1   s2250677
# 760 -23.656250      Thingy  Walking at normal speed              1   s2250677
#
#      notes                                       recording_id  mag_x   mag_y  \
# 0      NaN  Respeck_s2250677_Climbing stairs_04-10-2021_16...    NaN     NaN
# 1      NaN  Respeck_s2250677_Climbing stairs_04-10-2021_16...    NaN     NaN
# 2      NaN  Respeck_s2250677_Climbing stairs_04-10-2021_16...    NaN     NaN
# 3      NaN  Respeck_s2250677_Climbing stairs_04-10-2021_16...    NaN     NaN
# 4      NaN  Respeck_s2250677_Climbing stairs_04-10-2021_16...    NaN     NaN
# ..     ...                                                ...    ...     ...
# 756    NaN  Thingy_s2250677_Walking at normal speed_06-10-...   0.00  0.0000
# 757    NaN  Thingy_s2250677_Walking at normal speed_06-10-... -68.25 -3.5625
# 758    NaN  Thingy_s2250677_Walking at normal speed_06-10-...   0.00  0.0000
# 759    NaN  Thingy_s2250677_Walking at normal speed_06-10-...   0.00  0.0000
# 760    NaN  Thingy_s2250677_Walking at normal speed_06-10-...   0.00  0.0000
#
#        mag_z
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ..       ...
# 756    0.000
# 757 -140.875
# 758    0.000
# 759    0.000
# 760    0.000
#
# [27432 rows x 16 columns]

# %%
base_df.reset_index(drop=True, inplace=True)
base_df
# Out:
#            timestamp   accel_x   accel_y   accel_z     gyro_x     gyro_y  \
# 0      1633357398910 -0.291992 -1.111877  0.116394   2.750000   0.468750
# 1      1633357398943 -0.238525 -1.236389  0.010193  11.781250  -1.734375
# 2      1633357399015 -0.321045 -1.407288 -0.164124   1.984375   5.203125
# 3      1633357399020  0.040039 -1.713440 -0.226868   9.171875   7.953125
# 4      1633357399094 -0.019531 -1.135315 -0.065491   3.703125  -6.703125
# ...              ...       ...       ...       ...        ...        ...
# 27427  1633520435008 -1.315430 -0.021484  0.819336 -15.218750  -8.218750
# 27428  1633520435069 -0.703125 -0.136719 -0.393555 -22.687500 -28.000000
# 27429  1633520435097 -0.994141  0.189453  0.054688  49.468750  62.250000
# 27430  1633520435129 -1.173828  0.170898  0.018555 -17.781250  84.062500
# 27431  1633520435188 -0.809570  0.211914  0.183594 -24.687500  70.500000
#
#           gyro_z sensor_type            activity_type  activity_code  \
# 0       4.625000     Respeck          Climbing stairs             12
# 1       9.546875     Respeck          Climbing stairs             12
# 2      14.468750     Respeck          Climbing stairs             12
# 3      16.796875     Respeck          Climbing stairs             12
# 4     -11.781250     Respeck          Climbing stairs             12
# ...          ...         ...                      ...            ...
# 27427  36.937500      Thingy  Walking at normal speed              1
# 27428 -12.562500      Thingy  Walking at normal speed              1
# 27429  21.500000      Thingy  Walking at normal speed              1
# 27430 -12.437500      Thingy  Walking at normal speed              1
# 27431 -23.656250      Thingy  Walking at normal speed              1
#
#       subject_id  notes                                       recording_id  \
# 0       s2250677    NaN  Respeck_s2250677_Climbing stairs_04-10-2021_16...
# 1       s2250677    NaN  Respeck_s2250677_Climbing stairs_04-10-2021_16...
# 2       s2250677    NaN  Respeck_s2250677_Climbing stairs_04-10-2021_16...
# 3       s2250677    NaN  Respeck_s2250677_Climbing stairs_04-10-2021_16...
# 4       s2250677    NaN  Respeck_s2250677_Climbing stairs_04-10-2021_16...
# ...          ...    ...                                                ...
# 27427   s2250677    NaN  Thingy_s2250677_Walking at normal speed_06-10-...
# 27428   s2250677    NaN  Thingy_s2250677_Walking at normal speed_06-10-...
# 27429   s2250677    NaN  Thingy_s2250677_Walking at normal speed_06-10-...
# 27430   s2250677    NaN  Thingy_s2250677_Walking at normal speed_06-10-...
# 27431   s2250677    NaN  Thingy_s2250677_Walking at normal speed_06-10-...
#
#        mag_x   mag_y    mag_z
# 0        NaN     NaN      NaN
# 1        NaN     NaN      NaN
# 2        NaN     NaN      NaN
# 3        NaN     NaN      NaN
# 4        NaN     NaN      NaN
# ...      ...     ...      ...
# 27427   0.00  0.0000    0.000
# 27428 -68.25 -3.5625 -140.875
# 27429   0.00  0.0000    0.000
# 27430   0.00  0.0000    0.000
# 27431   0.00  0.0000    0.000
#
# [27432 rows x 16 columns]

# %% [markdown]
# ## Use Only Respeck Data

# %%
base_df = base_df[base_df['sensor_type'] == 'Respeck']

# %% [markdown]
# ## Get Example Dataframe

# %%
example_recording = base_df[base_df.activity_code == 1]

# %%
window_size = 50 # 50 datapoints for the window size, which, at 25Hz, means 2 seconds
step_size = 25 # this is 50% overlap

window_number = 0 # start a counter at 0 to keep track of the window number

large_enough_windows = [window for window in example_recording.rolling(window=window_size, min_periods=window_size) if len(window) == window_size]

# %%
overlapping_windows = large_enough_windows[::step_size] # Get every 25th item

# %%
for window in overlapping_windows:
    window.loc[:, 'window_id'] = window_number
    window_number += 1

# %%
final_sliding_windows = pd.concat(overlapping_windows).reset_index(drop=True)

# %%
first_four_windows = [group for window_id, group in final_sliding_windows[final_sliding_windows.window_id < 4].groupby("window_id")]
fig, ax = plt.subplots(1, 4, figsize=(20, 6))

for i in range(4):
    ax[i].plot(first_four_windows[i]['gyro_x'])
    ax[i].plot(first_four_windows[i]['gyro_y'])
    ax[i].plot(first_four_windows[i]['gyro_z'])
    ax[i].set_title(f"Window number = {first_four_windows[i].window_id.values[0]}")

# %%
columns_of_interest = ['accel_x', 'accel_y', 'accel_z', 'gyro_x', 'gyro_y', 'gyro_z']

# %%
np.array(first_four_windows[0][columns_of_interest]).shape
# Out:
# (50, 6)
